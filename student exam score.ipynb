# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
df=pd.read_csv("C:\\Users\\user\\Downloads\\exams.csv")
print(df)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group D                some college      standard
# 1      male        group D          associate's degree      standard
# 2    female        group D                some college  free/reduced
# 3      male        group B                some college  free/reduced
# 4    female        group D          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                some college      standard
# 996    male        group C                some college      standard
# 997  female        group A                 high school      standard
# 998    male        group E                 high school      standard
# 999    male        group D                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
print(df)
print(df.head())
print(df.tail())
print(df.shape)
print(df.columns)
print(df.isnull().sum())
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group D                some college      standard
# 1      male        group D          associate's degree      standard
# 2    female        group D                some college  free/reduced
# 3      male        group B                some college  free/reduced
# 4    female        group D          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                some college      standard
# 996    male        group C                some college      standard
# 997  female        group A                 high school      standard
# 998    male        group E                 high school      standard
# 999    male        group D                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.drop(["lunch","math score","reading score"],axis=1,inplace=True)
print(df)
# Out:
#      gender race/ethnicity parental level of education  \
# 0    female        group D                some college
# 1      male        group D          associate's degree
# 2    female        group D                some college
# 3      male        group B                some college
# 4    female        group D          associate's degree
# ..      ...            ...                         ...
# 995    male        group C                some college
# 996    male        group C                some college
# 997  female        group A                 high school
# 998    male        group E                 high school
# 999    male        group D                 high school
#
#     test preparation course  writing score
# 0                 completed             78
# 1                      none             87
# 2                      none             77
# 3                      none             63
# 4                      none             86
# ...

# %%
c=LabelEncoder()
df["gender"]=c.fit_transform(df["gender"])
df["race/ethnicity"]=c.fit_transform(df["race/ethnicity"])
df["parental level of education"]=c.fit_transform(df["parental level of education"])
df["test preparation course"]=c.fit_transform(df["test preparation course"])
df["writing score"]=c.fit_transform(df["writing score"])
print(df)
# Out:
#      gender  race/ethnicity  parental level of education  \
# 0         0               3                            4
# 1         1               3                            0
# 2         0               3                            4
# 3         1               1                            4
# 4         0               3                            0
# ..      ...             ...                          ...
# 995       1               2                            4
# 996       1               2                            4
# 997       0               0                            2
# 998       1               4                            2
# 999       1               3                            2
#
#      test preparation course  writing score
# 0                          0             51
# 1                          1             60
# 2                          1             50
# 3                          1             36
# 4                          1             59
# ...

# %%
x=df.drop("writing score",axis=1)
y=df["writing score"]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print(len(x_train))
print(len(y_train))
# Out:
# 800
# 800

# %%
model = LinearRegression() 
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r_sqr = r2_score(y_test, y_pred)

print("MSE:", mse)
print("MAE:", mae)
print("R_square:", r_sqr)
# Out:
# MSE: 150.8400157004248
# MAE: 9.92477977362107
# R_square: 0.19528129034303088
